# %%
import pandas as pd
s=pd.Series(['a',1,3.5,'new'])
s
# Out:
# 3.5

# %%
df=pd.DataFrame({
    'name':['rob','stark','jaimy','luna'],
    'age':[23,55,18,32],
    'zip code':[123,456,789,122]
})
df
# Out:
#     name  age  zip code
# 0    rob   23       123
# 1  stark   55       456
# 2  jaimy   18       789
# 3   luna   32       122

# %%
df['zip code']
# Out:
# 0    123
# 1    456
# 2    789
# 3    122
# Name: zip code, dtype: int64

# %%
table=pd.read_csv("/home/billion/extractor_configs_old_202205041714.csv")
table
# Out:
#         id              name                              doc_type  \
# 0        1           BrwName  Uniform_Residential_Loan_Application
# 1        2          BrwName2  Uniform_Residential_Loan_Application
# 2        3       DateofBirth  Uniform_Residential_Loan_Application
# 3        4       DateofBirth  Uniform_Residential_Loan_Application
# 4        5         HomePhone  Uniform_Residential_Loan_Application
# ...    ...               ...                                   ...
# 1090  1557           grantor                                  Deed
# 1091  1561           grantor                                  Deed
# 1092  1619           grantor                                  Deed
# 1093  1617           grantor                                  Deed
# 1094  1412  property_address                                  Deed
#
#      valid_pages  source_page_resolution  key_type  \
# 0            all                     800  variable
# 1            all                     800  variable
# ...

# %%
tb=pd.read_table("https://bit.ly/movieusers",sep='|',header=None)
tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       943 non-null    int64
#  1   1       943 non-null    int64
#  2   2       943 non-null    object
#  3   3       943 non-null    object
#  4   4       943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB
