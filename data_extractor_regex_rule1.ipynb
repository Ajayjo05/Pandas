# %%
import pandas as pd
import sqlalchemy
#from sqlalchemy import create_engine
from pandasql import sqldf   #pip install pandasql


    # Create the engine to connect to the PostgreSQL database
engine = sqlalchemy.create_engine('postgresql://postgres:password@172.17.0.1:5432/pf')
                                 #(database://usename:password@host:port/databaseName )
     
    # Read data from SQL table
#sql_data = pd.read_sql_table('data_extractor_regex_rules',engine,schema=None, index_col=None,coerce_float=True, parse_dates=None, columns=None,chunksize=None)
sq=pd.read_sql_query("select * from data_extractor_regex_rules1",engine)
sq

#if we limit the data while fetching using read_sql_query then filtering would be applied on the fetched data only i.e up to limit only.
#while if we use read_sql_table the filter is applied on all the data irrespective of the limit we have used in sqldf().
# Out:
#         id       doc_type             field_name  enabled valid_pages  \
# 0        1  Deed of trust                    apn     True       [all]
# 1        2  Deed of trust                trustor     True         [1]
# 2        3           Deed              deed_type     True         [0]
# 3        4  Deed of trust  recorded_requested_by     True       [all]
# 4        5  Deed of trust                trustor     True   [0, 1, 3]
# ...    ...            ...                    ...      ...         ...
# 997    998  Deed of trust      legal_description    False       [all]
# 998    999  Deed of trust      legal_description    False       [all]
# 999   1000           Deed      legal_description    False       [all]
# 1000  1001           Deed      legal_description     True       [all]
# 1001  1002           Deed      legal_description    False       [all]
#
#       rule_priority  source_page_resolution   key_type  \
# 0                 4                     200   variable
# ...

# %% [markdown]
# ######

# %%
#sq[(sq.doc_type=="Deed") & (sq.field_name=="vesting")].groupby(['field_name','key_regex']).size().reset_index(name="count")
#both works same. 
sq[(sq['doc_type']=="Deed") & (sq['field_name']=="vesting")].groupby(['field_name','key_regex']).size().reset_index(name="count")
# Out:
#    field_name                                          key_regex  count
# 0     vesting                                  (?i)(Grantee[\W])      1
# 1     vesting         (?i)(Grantee[\W]*\swhether\sone\sor\smore)      1
# 2     vesting                             (?i)(convey\sunto[\W])      1
# 3     vesting                                  (?i)(grantee[s]?)      2
# 4     vesting      (?i)(hereby\sconvey\sto\s|hereby\sconveyto\s)      1
# 5     vesting        (?i)(hereinafter\scalled\sthe\sGrantee[\W])      1
# 6     vesting    (?i)(hereinafter\scalled\sthe\s[\W]Grantee[\W])      1
# 7     vesting                          (?i)(warrant[\W]s[\W]*to)      1
# 8     vesting             (?i)(warrant[\W]s[\W]*to)|warrants\sto      1
# 9     vesting  (?i)GRANT,\sSELL\sAND\sCONVEY\sunto|hereby\sGR...      1
# 10    vesting  (?i)GRANT,\sSELL\sAND\sCONVEY\sunto|hereby\sGR...      1
# 11    vesting                                        (?i)GRANTEE      1
# ...

# %%
#to read from platform_fields table.
pf=pd.read_sql_query("select * from platform_fields",engine)
pf
# Out:
#       id                              doc_type                     field_name  \
# 0      1  Uniform_Residential_Loan_Application                        BrwName
# 1      2  Uniform_Residential_Loan_Application                       BrwName2
# 2      3  Uniform_Residential_Loan_Application                    DateofBirth
# 3      4  Uniform_Residential_Loan_Application                    DateofBirth
# 4      5  Uniform_Residential_Loan_Application                      HomePhone
# ..   ...                                   ...                            ...
# 138  139                                 IEADS                 balance_column
# 139  140                                 IEADS            payment_date_column
# 140  141                                 IEADS  withdrawal_description_column
# 141  142                                 IEADS      Mortgage_insurance_column
# 142  143                                 IEADS                 deposit_column
#
# ...

# %%
merged=pd.merge(sq,pf,how='left',on=['field_name','doc_type','config_set'])
merged
# Out:
#       id_x       doc_type             field_name  enabled_x valid_pages  \
# 0        1  Deed of trust                    apn       True       [all]
# 1        2  Deed of trust                trustor       True         [1]
# 2        3           Deed              deed_type       True         [0]
# 3        4  Deed of trust  recorded_requested_by       True       [all]
# 4        5  Deed of trust                trustor       True   [0, 1, 3]
# ...    ...            ...                    ...        ...         ...
# 1002   998  Deed of trust      legal_description      False       [all]
# 1003   999  Deed of trust      legal_description      False       [all]
# 1004  1000           Deed      legal_description      False       [all]
# 1005  1001           Deed      legal_description       True       [all]
# 1006  1002           Deed      legal_description      False       [all]
#
#       rule_priority  source_page_resolution   key_type  \
# ...

# %%
merged[(merged.doc_type=="Deed") & (merged.rule_priority>=6) & (merged.key_type=="variable")]
# Out:
#       id_x doc_type         field_name  enabled_x valid_pages  rule_priority  \
# 2        3     Deed          deed_type       True         [0]              6
# 13      13     Deed            grantor       True         [1]             10
# 14      14     Deed            vesting       True      [0, 1]             10
# 26      24     Deed              state       True      [0, 1]              8
# 31      29     Deed            grantee       True      [0, 1]             10
# ...    ...      ...                ...        ...         ...            ...
# 942    938     Deed          deed_type       True      [0, 1]             15
# 944    940     Deed             volume       True         [0]              6
# 985    981     Deed  legal_description       True       [all]             10
# 991    987     Deed  legal_description       True         [0]              8
# 1001   997     Deed  legal_description       True       [all]              6
#
#       source_page_resolution  key_type  \
# ...

# %%
#df1.join(df2,on=col1,how='inner')
# a=sq.join(pf,on=['field_name'],how='left',lsuffix='_')
# a

# %%
#to print the list of all columns we can use sq.info()

names=sq.field_name.unique().tolist()
names
# Out:
# ['apn',
#  'trustor',
#  'deed_type',
#  'recorded_requested_by',
#  'grantor',
#  'HomePhone',
#  'trustee',
#  'document_date_recorded',
#  'instrument_number',
#  'vesting',
#  'transfer_tax',
#  'county',
#  'beneficiary',
#  'grantee',
#  'state',
#  'seller',
#  'property_address',
#  'amount',
#  'dated_date',
#  'volume',
#  'book',
#  'document_created_date',
#  'rider_mobile_home',
#  'borrower',
#  'DateofBirth',
#  'rider_renewal_and_extension',
#  'stamp_value',
#  'hazard_insurance_column',
#  'rider_planned_unit_development',
#  'rider_v_a',
#  'withdrawal_column',
#  'co_borrower',
#  'loan_number',
#  'name_of_trust',
#  'min_number',
#  'DocumentGUID',
#  'rider_ballon',
#  'rider_condominium',
#  'county_tax_impounds_column',
#  'BrwName2',
#  'Social Security Number',
#  'rider_second_home',
#  'balance_column',
#  'payment_date_column',
#  'BrwName',
#  'initial_balance',
#  'withdrawal_description_column',
#  'rider_adjustable_rate',
#  'rider_1_to_4_family',
# ...

# %%
#df.sort_values(by="city08",ascending=False)
sq.sort_values(by=["field_name"],ascending=False).head(30)
# Out:
#       id       doc_type                     field_name  enabled valid_pages  \
# 721  721          IEADS  withdrawal_description_column     True         [0]
# 176  177          IEADS              withdrawal_column     True         [0]
# 273  272  Deed of trust                         volume     True         [0]
# 725  725  Deed of trust                         volume     True         [0]
# 49    49           Deed                         volume     True         [0]
# 51    51           Deed                         volume     True         [0]
# 905  906           Deed                         volume     True         [0]
# 695  694  Deed of trust                         volume     True         [0]
# 608  604           Deed                         volume     True   [3, 4, 5]
# 951  952  Deed of trust                         volume     True         [0]
# 950  951  Deed of trust                         volume    False         [0]
# ...

# %%
#sq.filter(items=['doc_type'])
sq.groupby('doc_type').size()
# Out:
# doc_type
# Compliance_Report                         2
# Deed                                    437
# Deed of trust                           524
# FINAL CLOSING STATEMENT                   3
# Form-1040                                 1
# Form-W2                                   1
# IEADS                                    10
# Real Estate Commission Disbursement       3
# TAX_CERTIFICATION                        13
# TEXAS NOTICE                              1
# Uniform_Residential_Loan_Application      7
# dtype: int64
