# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
from pandasql import sqldf   #pip install pandasql

    
    # Create the engine to connect to the PostgreSQL database
engine = sqlalchemy.create_engine('postgresql://postgres:password@172.17.0.1:5432/pf')
                                 #(database://usename:password@host:port/databaseName )
     
    # Read data from SQL table
sql_data = pd.read_sql_table('extractor_configs_old',engine)
#sql_write=sql_data.to_sql('extractor_configs_old',engine,index=False,if_exists='append')
sql_data

# engine.execute("alter table sql_data ADD ajay VARCHAR(25)")
#engine.execute("SELECT * FROM sql_data LIMIT 2")
# q = "SELECT * FROM sql_data LIMIT 5"
# sqldf(q)
# Out:
#         id              name                              doc_type  \
# 0        1           BrwName  Uniform_Residential_Loan_Application
# 1        2          BrwName2  Uniform_Residential_Loan_Application
# 2        3       DateofBirth  Uniform_Residential_Loan_Application
# 3        4       DateofBirth  Uniform_Residential_Loan_Application
# 4        5         HomePhone  Uniform_Residential_Loan_Application
# ...    ...               ...                                   ...
# 1090  1557           grantor                                  Deed
# 1091  1561           grantor                                  Deed
# 1092  1619           grantor                                  Deed
# 1093  1617           grantor                                  Deed
# 1094  1412  property_address                                  Deed
#
#      valid_pages  source_page_resolution  key_type  \
# 0            all                     800  variable
# 1            all                     800  variable
# ...

# %%
f1=sql_data[(sql_data.source_page_resolution>500)&(sql_data.confidence_score>70)]
f1
# Out:
#    id                    name                              doc_type  \
# 0   1                 BrwName  Uniform_Residential_Loan_Application
# 1   2                BrwName2  Uniform_Residential_Loan_Application
# 2   3             DateofBirth  Uniform_Residential_Loan_Application
# 3   4             DateofBirth  Uniform_Residential_Loan_Application
# 4   5               HomePhone  Uniform_Residential_Loan_Application
# 5   6               HomePhone  Uniform_Residential_Loan_Application
# 6   7  Social Security Number  Uniform_Residential_Loan_Application
#
#   valid_pages  source_page_resolution  key_type  \
# 0         all                     800  variable
# 1         all                     800  variable
# 2         all                     800  variable
# 3         all                     800  variable
# 4           1                     800  variable
# 5         all                     800  variable
# 6           0                     800  variable
#
# ...

# %%
col=['user_id','age','gender','occupation','pin_code']
user=pd.read_table('https://bit.ly/movieusers', sep='|', header=None, names=col)
user.head(10)
# Out:
#    user_id  age gender     occupation pin_code
# 0        1   24      M     technician    85711
# 1        2   53      F          other    94043
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 4        5   33      F          other    15213
# 5        6   42      M      executive    98101
# 6        7   57      M  administrator    91344
# 7        8   36      M  administrator    05201
# 8        9   29      M        student    01002
# 9       10   53      M         lawyer    90703

# %%
# fi=user[(user['age']>55) & (user['gender']=="F")]
# fi

# fi=user[(user.age>55) & (user.gender=="F")]     #both works same.
# fi

f=user.groupby(['age','gender']).size().reset_index(name='counts') #for row count
f.head()
# Out:
#    age gender  counts
# 0    7      M       1
# 1   10      M       1
# 2   11      M       1
# 3   13      F       2
# 4   13      M       3

# %%
# f=user.query('age==55 & gender=="F"')
# f
f="select * from user where pin_code==15237"
sqldf(f)
# Out:
#    user_id  age gender     occupation pin_code
# 0      131   59      F  administrator    15237

# %%
f1=sql_data[(sql_data.source_page_resolution>500)&(sql_data.confidence_score>70)]
f1
# Out:
#    id                    name                              doc_type  \
# 0   1                 BrwName  Uniform_Residential_Loan_Application
# 1   2                BrwName2  Uniform_Residential_Loan_Application
# 2   3             DateofBirth  Uniform_Residential_Loan_Application
# 3   4             DateofBirth  Uniform_Residential_Loan_Application
# 4   5               HomePhone  Uniform_Residential_Loan_Application
# 5   6               HomePhone  Uniform_Residential_Loan_Application
# 6   7  Social Security Number  Uniform_Residential_Loan_Application
#
#   valid_pages  source_page_resolution  key_type  \
# 0         all                     800  variable
# 1         all                     800  variable
# 2         all                     800  variable
# 3         all                     800  variable
# 4           1                     800  variable
# 5         all                     800  variable
# 6           0                     800  variable
#
# ...

# %%
sq='select name,doc_type,config_set from sql_data where name=="grantee" and doc_type=="Deed" and config_set=="Fluid" limit 5'
sqldf(sq)
# Out:
#       name doc_type config_set
# 0  grantee     Deed      Fluid
# 1  grantee     Deed      Fluid
# 2  grantee     Deed      Fluid
# 3  grantee     Deed      Fluid
# 4  grantee     Deed      Fluid

# %%
f=sql_data.groupby(['name','doc_type']).size().reset_index(name='counts')     #without reset_index shows count without header
f.head(50)                                                           #size() counts the rows
# Out:
#                          name                              doc_type  counts
# 0                  AmountOwed                             Form-1040       1
# 1                     BrwName  Uniform_Residential_Loan_Application       1
# 2                    BrwName2  Uniform_Residential_Loan_Application       1
# 3                 DateofBirth  Uniform_Residential_Loan_Application       2
# 4                DocumentGUID                             Form-1040       1
# 5                DocumentType                               Form-W2       1
# 6           EmployeeCitySTZIP                               Form-W2       1
# 7           EmployeeFirstName                               Form-W2       1
# 8            EmployeeLastName                               Form-W2       1
# 9                 EmployeeSSN                               Form-W2       1
# 10                EmployerEIN                               Form-W2       1
# ...

# %%
#This is available from pandas 1.1 if you just want to capture the size of every group, 
#this cuts out the GroupBy and is faster.
#df.value_counts(subset=['col1', 'col2'])
sql_data.value_counts(subset=['name','doc_type']).reset_index(name='counts')
# Out:
#                   name                             doc_type  counts
# 0          beneficiary                        Deed of trust      73
# 1    instrument_number                        Deed of trust      64
# 2              trustee                        Deed of trust      53
# 3                  apn                                 Deed      52
# 4                  apn                        Deed of trust      52
# ..                 ...                                  ...     ...
# 98         co_borrower              FINAL CLOSING STATEMENT       1
# 99            borrower  Real Estate Commission Disbursement       1
# 100               book                  Deed of trust||Deed       1
# 101     balance_column                                IEADS       1
# 102         AmountOwed                            Form-1040       1
#
# [103 rows x 3 columns]

# %%
# find total apn grouped by doc_type
#sql_data[sql_data.name=="apn"].groupby(['name','doc_type']).size().reset_index(name="count") 
sql_data[(sql_data['name']=='apn')&(sql_data['key_type']=='variable')].groupby(['name','doc_type','key_type']).size().reset_index(name="count") #both ways works
# Out:
#   name       doc_type  key_type  count
# 0  apn           Deed  variable     50
# 1  apn  Deed of trust  variable     46

# %%
#to find the number of rules where valid pages are "Zero".
sql_data[sql_data.valid_pages=="0"].groupby(['name','doc_type','config_set']).size().reset_index(name="counts")
# Out:
#                           name                              doc_type  \
# 0               HomeAddressApt                             Form-1040
# 1         HomeAddressCitySTZIP                             Form-1040
# 2            HomeAddressStreet                             Form-1040
# 3    Mortgage_insurance_column                                 IEADS
# 4             PrimaryFirstName                             Form-1040
# 5              PrimaryLateName                             Form-1040
# 6                   PrimarySSN                             Form-1040
# 7       Social Security Number  Uniform_Residential_Loan_Application
# 8              SpouseFirstName                             Form-1040
# 9               SpouseLateName                             Form-1040
# 10                   SpouseSSN                             Form-1040
# 11                      amount                                  Deed
# 12                      amount                         Deed of trust
# ...

# %%
#Find the field where field_name= vesting and group by name
sql_data[(sql_data['name']=="vesting")&(sql_data['doc_type']=="Deed of trust")].groupby(['name']).size().reset_index(name="count")
# Out:
#       name  count
# 0  vesting     39
