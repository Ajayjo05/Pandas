# %%
import pandas as pd
import sqlalchemy
engine=sqlalchemy.create_engine("postgres://postgres:password@172.17.0.1:5432/pf")
derr=pd.read_sql_table('data_extractor_regex_rules1',engine)
derr
# Out:
#         id       doc_type             field_name  enabled valid_pages  \
# 0        1  Deed of trust                    apn     True       [all]
# 1        2  Deed of trust                trustor     True         [1]
# 2        3           Deed              deed_type     True         [0]
# 3        4  Deed of trust  recorded_requested_by     True       [all]
# 4        5  Deed of trust                trustor     True   [0, 1, 3]
# ...    ...            ...                    ...      ...         ...
# 997    998  Deed of trust      legal_description    False       [all]
# 998    999  Deed of trust      legal_description    False       [all]
# 999   1000           Deed      legal_description    False       [all]
# 1000  1001           Deed      legal_description     True       [all]
# 1001  1002           Deed      legal_description    False       [all]
#
#       rule_priority  source_page_resolution   key_type  \
# 0                 4                     200   variable
# ...

# %%
# filtering data on the basis of given condition
derr[(derr.doc_type=="Deed")&(derr.field_name=="apn")]
# Out:
#       id doc_type field_name  enabled valid_pages  rule_priority  \
# 17    18     Deed        apn     True         [0]              5
# 19    35     Deed        apn     True       [all]              5
# 34    33     Deed        apn     True         [0]              5
# 46    46     Deed        apn     True         [0]              4
# 71    71     Deed        apn     True       [all]              5
# 82    83     Deed        apn     True       [all]              5
# 84    85     Deed        apn     True       [all]              4
# 99    99     Deed        apn     True       [all]              5
# 115  115     Deed        apn     True         [0]              5
# 120  120     Deed        apn     True         [0]              4
# 155  152     Deed        apn     True         [0]              5
# 167  168     Deed        apn     True         [0]              5
# 211  212     Deed        apn     True         [0]              5
# ...

# %%
#filtering data with conditions and groupby can be considered as where condition
derr[(derr.doc_type=="Deed")&(derr.field_name=="grantee")&(derr.key_type=="variable")].groupby(['field_name','key_regex']).size().reset_index(name="count")
# Out:
#    field_name                                          key_regex  count
# 0     grantee                  (?i)(Grantee[\W])|first part, and      1
# 1     grantee         (?i)(Grantee[\W]*\swhether\sone\sor\smore)      2
# 2     grantee                         (?i)(hereby\sconvey\sto\s)      2
# 3     grantee        (?i)(hereinafter\scalled\sthe\sGrantee[\W])      1
# 4     grantee    (?i)(hereinafter\scalled\sthe\s[\W]Grantee[\W])      2
# 5     grantee       (?i)(hereinafter\sreferred\sto\sas\sGrantee)      2
# 6     grantee                          (?i)(warrant[\W]s[\W]*to)      1
# 7     grantee  (?i)(warrants[\W]to[\W])|general\swarranty\sco...      1
# 8     grantee                       (?i)AND FOREVER QUITCLAIM to      2
# 9     grantee  (?i)GRANT,\sSELL\sAND\sCONVEY\sunto|hereby\sGR...      1
# 10    grantee  (?i)GRANT,\sSELL\sAND\sCONVEY\sunto|hereby\sGR...      1
# 11    grantee  (?i)Grantee:|Grantees|[\W][\W]Grantees[\W][\W]...      1
# ...

# %%
#sorting values for the fields field name, doc_type
sort=derr.sort_values(['field_name','doc_type'])[['field_name','doc_type']]   # [['field_name','doc_type']] To show only particular columns
sort.head(50)
# Out:
#                     field_name                              doc_type
# 691                    BrwName  Uniform_Residential_Loan_Application
# 301                   BrwName2  Uniform_Residential_Loan_Application
# 114                DateofBirth  Uniform_Residential_Loan_Application
# 160                DateofBirth  Uniform_Residential_Loan_Application
# 212               DocumentGUID                             Form-1040
# 861              Employer Name                               Form-W2
# 7                    HomePhone  Uniform_Residential_Loan_Application
# 848                  HomePhone  Uniform_Residential_Loan_Application
# 798  Mortgage_insurance_column                                 IEADS
# 395     Social Security Number  Uniform_Residential_Loan_Application
# 413                     amount                                  Deed
# 419                     amount                                  Deed
# 495                     amount                                  Deed
# ...

# %%
#derr.filter(items=['id','doc_type'])
derr['id'] #to select a data series from a dataframe
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 997      998
# 998      999
# 999     1000
# 1000    1001
# 1001    1002
# Name: id, Length: 1002, dtype: int64

# %%
derr.sort_values(by=['id','doc_type'],ascending=[False,False])[['id','doc_type']]
# Out:
#         id       doc_type
# 1001  1002           Deed
# 1000  1001           Deed
# 999   1000           Deed
# 998    999  Deed of trust
# 997    998  Deed of trust
# ...    ...            ...
# 4        5  Deed of trust
# 3        4  Deed of trust
# 2        3           Deed
# 1        2  Deed of trust
# 0        1  Deed of trust
#
# [1002 rows x 2 columns]

# %%
#filtering the colums from the dataset
derr.filter(['id','key_position'])
# Out:
#         id             key_position
# 0        1  [177, 2362, 1446, 2416]
# 1        2    [5, 1283, 2600, 1656]
# 2        3      [18, 12, 1686, 931]
# 3        4     [127, 496, 854, 690]
# 4        5   [95, 1012, 1674, 1639]
# ...    ...                      ...
# 997    998    [659, 350, 1006, 787]
# 998    999    [659, 350, 1006, 787]
# 999   1000    [659, 350, 1006, 787]
# 1000  1001   [103, 1090, 545, 1124]
# 1001  1002    [659, 350, 1006, 787]
#
# [1002 rows x 2 columns]

# %%
#Pandas groupby is used for grouping the data according to the categories and apply a function to the categories.

# %%
derr.groupby(['field_name','doc_type']).size()
# Out:
# field_name                     doc_type
# BrwName                        Uniform_Residential_Loan_Application     1
# BrwName2                       Uniform_Residential_Loan_Application     1
# DateofBirth                    Uniform_Residential_Loan_Application     2
# DocumentGUID                   Form-1040                                1
# Employer Name                  Form-W2                                  1
#                                                                        ..
# vesting                        Deed of trust                           31
# volume                         Deed                                    12
#                                Deed of trust                           10
# withdrawal_column              IEADS                                    1
# withdrawal_description_column  IEADS                                    1
# Length: 78, dtype: int64

# %%
derr.filter(regex='pe$', axis=1)
# Out:
#            doc_type   key_type value_type value_data_type
# 0     Deed of trust   variable       text  numeric_string
# 1     Deed of trust   variable       text            name
# 2              Deed   variable       text          string
# 3     Deed of trust   variable       text    organisation
# 4     Deed of trust   variable       text          string
# ...             ...        ...        ...             ...
# 997   Deed of trust  variable_       text          string
# 998   Deed of trust  variable_       text          string
# 999            Deed  variable_       text          string
# 1000           Deed   variable       text          string
# 1001           Deed  variable_       text          string
#
# [1002 rows x 4 columns]
